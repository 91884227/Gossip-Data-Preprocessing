# %% [markdown]
# # import tool

# %%
import pandas as pd
import numpy as np
import re
from itertools import compress
from tqdm import tqdm
import sys

# %%
def str_contain_keyword(str_):
    conditions = ["[新聞]", "Re:", "[公告]", "Fw:"]
    #global CONDITIONS
    #conditions = CONDITIONS
    buf = any([str_.startswith(i)  for i in conditions])
    return(buf)

# %%
def str_adjust(str_):
    buf = str_
    try:
        m = re.match(r'(\[.*\] ?)(.*)', str_)
        buf = m.group(2)
#         if(len(buf) < 5):
#             print("to short: %s\n" % str_)
    except:
        pass
        #print("error happend: %s\n" % str_)
        #print("error happend")
    return(buf)

# %%
#if __name__ == '__main__':
    #FIALNAME =  sys.argv[1]
    FIALNAME = "Gossip_title_30000_to_39040.csv"
    
    MIN_LENGTH = 10
    CONDITIONS = ["[新聞]",  "Re:",  "[公告]",  "Fw:"]

    print("read %s in " % FIALNAME)
    df = pd.read_csv(FIALNAME, encoding="utf-8")
    #df = pd.read_csv(FIALNAME, encoding="gb2312")
    title = df.title.to_numpy()

    print("delete title starting with %s" %  CONDITIONS)
    bool_want = [not str_contain_keyword(i) for i in tqdm(title)]
    title_A = list(compress(title, bool_want))

    print("adjust title e.g. %s " %  "[問卦] 國王的女兒說我性侵她該怎麼辦？ -> 國王的女兒說我性侵她該怎麼辦？")
    title_B = [str_adjust(i) for i in tqdm(title_A)]

    print("delete title that len(title) < %d" % MIN_LENGTH)
    title_length = [len(i) for i in title_B]
    bool_want = np.array(title_length) > 10
    title_C = list(compress(title_B, bool_want))

    # save
    name = "%s_adjust.npy" % FIALNAME[:-4]

    try:
        np.save(name, title_C)
        print("preprocessing successfully")
        print("save as %s" % name)
    except:
        print("preprocessing failed")
# Out:
# read Gossip_title_30000_to_39040.csv in
#  42%|█████████████████████████████▋                                         | 75470/180436 [00:00<00:00, 748972.22it/s]
# delete title starting with ['[新聞]', 'Re:', '[公告]', 'Fw:']
# 100%|██████████████████████████████████████████████████████████████████████| 180436/180436 [00:00<00:00, 735275.31it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 99902/99902 [00:00<00:00, 625994.39it/s]
# adjust title e.g. [問卦] 國王的女兒說我性侵她該怎麼辦？ -> 國王的女兒說我性侵她該怎麼辦？
# error happend: 怎麼避免屯積口罩
#
# error happend: re:[問卦] 跟著物流看各超商怎麼賣口罩？
#
# error happend: ［協尋］協尋狗狗遺失、新店
#
# error happend: 一次戴兩個口罩有用嗎
#
# error happend: ［新聞］超商明起不賣口罩！！改藥局實名制
#
# error happend: R: [新聞] 大陸公開求救 承認急需口罩、防護衣和護
#
# error happend: 最好的隔離所是太平島，對不對？
#
# error happend: 口罩價錢
#
# error happend: 台商聚集地 昆山 疑似封城
#
# error happend: 0
#
# error happend: 香港澳門人士可以來台嗎
#
# error happend: ［問卦］撤僑出包為何沒有政府官員出來解釋？
#
# error happend: 【問卦】買辦的最高境界
#
# error happend: ［問卦］疾管家 號碼牌
#
# error happend: 違反居家隔離規定直接公布姓名照片
#
# error happend:  [問卦] 便利商店集點換口罩有搞頭嗎？？
#
# error happend: 「問掛」陳部長的霸氣的八掛
#
# error happend: ［問卦］咖哩的真諦是什麼。
#
# error happend: 有沒有貓貓查水表的八卦R?
#
# error happend: 地震
#
# error happend: ［問掛］沒戴口罩484遊輪的肺炎早傳播了
#
# error happend: [徵求］ 行車記錄2/7 19:05 台北市民大道
#
# error happend: ［爆卦］口罩哪裡買？「口罩地圖」幫助你
#
# error happend: 有沒有炸雞排一個月5萬5的八卦？
#
# error happend: ［問卦］武漢肺炎一天的真實死亡數字疑
#
# error happend: ［問掛］去年罷工的華航機師和長榮空姐
#
# error happend: ［問卦］ 最受不了哪種中英混搭詞？
#
# error happend: 上個段子，數落中國共產黨
#
# error happend: 點放能去哪
#
# error happend: 額溫槍 黑人.JPG
#
# error happend: 有沒有小明是大胃王的八卦
#
# error happend: ［徵求］ 行車記錄器 國道北上17.7K
#
# error happend: ［新聞］25歲楊瓊瓔長這樣！網讚媲美子瑜
#
# error happend: (本文已被刪除) [Radiomir]
#
# error happend: 地震
#
# error happend: 地震
#
# error happend: 地震
#
# error happend: ［問掛］有沒有相似台灣和中國關係的歷史故事啊？
#
# error happend: 年幼姐弟是台獨同路人嗎？
#
# error happend: ［問卦］有沒有成語克漏字要怎麼做的八卦
#
# error happend: 情人節 聖誕節 春節 哪個對肥宅最不友善
#
# error happend: 地震
#
# error happend: 地震
#
# error happend: 地震
#
# error happend: 地震
#
# error happend: 地震
#
# error happend: 餘震
#
# error happend: 地震
#
# error happend: ［問卦] 宮崎駿電影中的女主角前三名是誰？
#
# error happend: ［問卦］明明還在疫調 為什麼都寫社區感染
#
# error happend: 岩田健太郎
#
# error happend: ［健康］手麻不能等 全民健康一起來
#
# error happend: ［問卦］阿輝伯還在嗎QQ
#
# error happend: [新聞］韓防疫本部：新天地信徒4475人544名有症
#
# error happend: (本文已被刪除) [Radiomir]
#
# error happend: 今天舉行228遊行的人在想什麼？
#
# error happend: [問卦］防疫視同做戰
#
# error happend:  [問卦] 欸！有沒有捷運上口罩變少的掛
#
# error happend: [問卦］醫護禁止出國法源？
#
# error happend: 開學了，雲林小孩竟然還需擔心這種事
#
# error happend: 地震
#
# error happend:    [問卦] 台灣的教育是不是太廢了台灣的教育是不是太廢了
#
# error happend: ［問卦］台灣醫護人員很衰小的掛？
#
# error happend: 地震
#
# error happend: 關於中國蝙蝠
#
# error happend: 請問有沒有打卡能在地圖顯示的部落格？
#
# error happend: 這敏感時期，室內聚會有必要參加嗎？
#
# error happend: [問卦］該怎麼面對堅持出國日本的台男？
#
# error happend: (本文已被刪除) [Radiomir]
#
# error happend: ［討論］中國開始傳說首例冠狀病毒來自美國...
#
# error happend: (本文已被刪除) [Radiomir]
#
# error happend: ［問掛］有沒有口罩分裝的八卦
#
# error happend: [問卦邱逢甲是怎樣的歷史人物？
#
# error happend: (本文已被刪除) [Radiomir]
#
# error happend: 誒誒誒淡水雨超大的啦
#
# error happend:  [爆掛]新論文:參宿四沒有要爆炸
#
# error happend: [問卦］台大法律是不是很鳥
#
# error happend: R: [新聞] 文化入侵 愛奇藝中劇簡體字幕近8成
#
# error happend: 今天的九點的股市開市
#
# error happend: ［新聞］NBA關門
#
# error happend: 六萬六可以幹嘛？
#
# error happend: ［爆卦］慟！台指夜盤正式跌破萬點了！
#
# error happend: 航海王跟獵人為什麼內容變那麼複雜
#
# error happend: 在歐洲，如何渡過這個月呢？
#
# error happend: 金門王的文章八掛
#
# error happend: 請問這兩天到底會不會下雨？
#
# error happend: [問卦］麥當勞麥脆雞餐
#
# error happend: 「問卦」早上進去搶反彈的，是不是都太貪婪
#
# error happend:  [問卦] 大學生沒用社交軟體的人多嗎？
#
# error happend: 懇求台灣不要補助回國居家隔離者
#
# error happend: (本文已被刪除) [Radiomir]
#
# error happend: R: [問卦] 什麼魚煮魚湯便宜又好吃？
#
# error happend: 地震
#
# error happend: (本文已被刪除) [Radiomir]
#
# error happend: R: [新聞] 又來挑釁！中國10餘艘快艇惡意攻擊
#
# error happend: 地震
#
# error happend: 到底是誰發明紫米飯的？
#
# error happend: ［爆卦］美濃疑似火燒山
#
# error happend: (本文已被刪除) [Radiomir]
#
# error happend:  [問卦] 五毛偽裝的台派有什麼特徵？
#
# error happend: (本文已被刪除) [Radiomir]
#
# error happend: 人生的伴侶該如何選擇？
#
# error happend: Line是不是又盪G啊？
#
# error happend: 【問卦】扒手喜歡跑步的真諦是什麼。
#
# error happend: ［問卦］大雄媽不知道他兒子被霸凌？
#
# error happend: 分類到底是啥啊 能吃嗎
#
# error happend: (本文已被刪除) [Radiomir]
#
# error happend: ［問卦］櫛瓜被冷凍又解凍了還能吃嗎？
#
# error happend: ［問卦］為什麼街友有錢染頭髮？
#
# error happend: 地震
#
# error happend: 台南地震
#
# error happend: [問卦］請問D能卡這篇是在衝三
#
# error happend: 我教育你們這些人，為什麼要捐口罩啦
#
# error happend: 女保全是在哪個社區？有卦嗎？
#
# error happend: [新聞］發病12天才確診！日本女團感染武肺
#
# error happend: 詳實紀錄每一天路徑及接觸的人
#
# error happend: R: [問卦] 日本的鳥取縣是個什麼樣的地方 ?
#
# error happend: (本文已被刪除) [Radiomir]
#
# error happend: 是不是該全民戴口罩了
#
# error happend: [問卦］關於演習的八卦
#
# error happend: 閏五月為何不能分批放二次端午節呢
#
# error happend: 英國首相地位有多大？
#
# error happend: 有沒有神父要出征的掛?
#
# error happend: ［問卦］為什麼愛滋病毒要叫愛滋病毒？
#
# error happend: (本文已被刪除) [Radiomir]
#
# error happend: ［問卦］都可以線上認證 以後投票可否在家投
#
# error happend: 酒店行話？
#
# error happend: (本文已被刪除) [Radiomir]
#
# error happend:  [問卦] 你各位下午看到賓士貓心情愉快齁
#
# error happend: 電資到底憑什麼跟醫牙排一起
#
# error happend: 地震
#
# error happend: 怎麼要求政府去中國化
#
# error happend: R: 北市設口罩販賣機 柯:看一堆人排口罩受不了
#
# error happend: ［問掛］可以不要再貼習維尼的噁圖了
#
# error happend: ［問卦］痰要硬咳還是等想咳再咳出來？
#
# error happend: (本文已被刪除) [Radiomir]
#
# error happend: ｛問卦｝有沒有譚德塞不談疫情談歧視的八掛，”新加坡網民“居然跟
#
# error happend: R: [政治] 何晶其實沒刪「Errrr…」文！ 轉發近
#
# error happend: R: [問卦] 支持警察踹8+9頭的人是哪種人？
#
# error happend: 【問卦】有沒有公宅快要半夜一點還在施工的八卦?
#
# error happend: 4/11淡水關渡橋行車記錄器畫面
#
# error happend: R: [問卦] 2個小孩  請問誰說謊
#
# error happend: [新聞影／募4萬5千個物資挺醫護 盧秀燕鞠躬「有愛最重要」
#
# error happend: ［問卦］牧拿不到冠軍是隊友太廢嗎
#
# error happend:  [問卦] 樓梯懸案?
#
# error happend:  [協尋] 尋找媽媽 （台南市東區）
#
# error happend: 健保快易通
#
# error happend: 張經義的嘴
#
# delete title that len(title) < 10
# preprocessing successfully
# save as Gossip_title_30000_to_39040_adjust.npy
